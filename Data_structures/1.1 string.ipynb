# %% [markdown]
# # Strings are sequence of Characters
#
# In Python specifically, strings are a sequence of Unicode Characters
# 1. string immutable ahe tya mule-> string method use karatana je pan changes hotat perment nahi hot te tempory changes hotat
# - ->s = "pitambar salgare"
# -  -> print(s.capitalize())  -> ya sathi tempory memory location create hote to  function return or print hoto
#  - memory madhe
# - Creating Strings
# - Accessing Strings
# - Adding Chars to Strings
# - Editing Strings
# - Deleting Strings
# - Operations on Strings
# - String Functions

# %%
s = 'hello'
s = "hello"
# multiline strings
s = '''hello'''
s = """hello"""
s = str('hello')
print(s)
# Out:
# hello

# %%
# Positive Indexing
s = 'hello world'
print(s[10])
# Out:
# d

# %%
# Negative Indexing
s = 'hello world'
print(s[-3])
# Out:
# r

# %%
# Slicing
s = 'hello world'
print(s[6:0:-2])
# Out:
# wol

# %%
print(s[::-1])
# Out:
# dlrow olleh

# %%
# Slicing
s = 'hello world'
print(s[6:0:-2])
# Out:
# wol

# %% [markdown]
# 1. Editing and Deleting in Strings-> immutable ahe na tya mule

# %%
s = 'hello world'
s[0] = 'H'

# Python strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 s = 'hello world'
# ----> 2 s[0] = 'H'
#
# TypeError: 'str' object does not support item assignment

# %%
s = 'hello world'
del s
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 s = 'hello world'
#       2 del s
# ----> 3 print(s)
#
# NameError: name 's' is not defined

# %%
del s[-1:-5:2]    
print(s)    # slising ne delete karu shakat nahi re
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 s = 'hello world'
# ----> 2 del s[-1:-5:2]
#       3 print(s)    # slising ne delete karu shakat nahi re
#
# TypeError: 'str' object does not support item deletion

# %% [markdown]
# # Operations on Strings
#     Arithmetic Operations
#     Relational Operations
#     Logical Operations
#     Loops on Strings
#     Membership Operations

# %%
print('delhi' + ' ' + 'mumbai')   # (+) -> concatation ahe
# Out:
# delhi mumbai

# %%
print('delhi'*5)      # (*) -> multiple pan hoto
# Out:
# delhidelhidelhidelhidelhi

# %%
'delhi' != 'delhi'   # not equal to string madhe yeto  ahe
# Out:
# False

# %%
print('mumbai' > 'pune')
# lexiographically ((asiic value check keli ))
print('Pune' >= 'pune')
'Pune' >= 'Pune'
# Out:
# False
# False
# True

# %%
print('hello' and '') # op-> world

print('hello' or 'world')   #  o/p -> hello
print()
# Out:
# hello

# %%
'' or 'world'
# Out:
# 'world'

# %%
'' and 'world'
# Out:
# ''

# %%
not 'hello'
# Out:
# False

# %%
for i in 'delhi':
  print('pune')
# Out:
# pune
# pune
# pune
# pune
# pune

# %%
for i  in "india":
    print(i,end="-")
# Out:
# i-n-d-i-a-

# %% [markdown]
# # Common Functions
#     len
#     max
#     min
#     sorted

# %%
len('hello world')
# Out:
# 11

# %%
max('hello world')     # ascii value nusar ahe br ka
# Out:
# 'w'

# %%
min('hello world')
# Out:
# ' '

# %%
sorted('hello world')
# Out:
# [' ', 'd', 'e', 'h', 'l', 'l', 'l', 'o', 'o', 'r', 'w']

# %%
sorted('hello world',reverse=True) # sorting kart ahe highest value nusar ahe
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %% [markdown]
# # Capitalize/Title/Upper/Lower/Swapcase

# %%
s = "pitambar salgare"
print(s.capitalize())
print(s)
# Out:
# Pitambar salgare
# pitambar salgare

# %%
s.title()
# Out:
# 'Pitambar Salgare'

# %%
s.upper()
# Out:
# 'PITAMBAR SALGARE'

# %%
"PITAMBAR SALGARE".lower()
# Out:
# 'pitambar salgare'

# %%
'PiTaMBAR saLGAre'.swapcase()   # ya case madhe je lower ahe te upper hotay and jo upper ahe te lower hotya
# Out:
# 'pItAmbar SAlgaRE'

# %% [markdown]
# # Count/Find/Index

# %%
'my name is pitu'.count('i')
# Out:
# 2

# %%
'my name is pitu'.count('z')   # string madhe to char nasel tar zero yenar
# Out:
# 0

# %%
'my name is piru'.find('i')
# Out:
# 8

# %%
'my name is pitu'.find('x')   # eka string madhe  alphabet nasel tar (-1) yeto
# Out:
# -1

# %%
'my name is pitu'.index('i')
# Out:
# 8

# %%
'my name is piru'.index('x')   # index wala method ahe to (ValueError): substring not found
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 'my name is piru'.index('x')   # index wala method ahe to (ValueError): substring not found
#
# ValueError: substring not found

# %%
'my name is nvdf'.index('a')
# Out:
# 4

# %% [markdown]
# # endswith/ startswith / format

# %%
print('my name is pitu'.endswith('fsf'))
print('my name is pito'.endswith('to'))
# Out:
# False
# True

# %%
print('my name is piru'.startswith('1my'))
print('my name is pitu'.startswith('my'))
# Out:
# False
# True

# %%
name = 'pitu'
gender = 'male'

'Hi my name is {1} and I am a {0}'.format(gender,name)
# Out:
# 'Hi my name is pitu and I am a male'

# %% [markdown]
# # Replace

# %%
'hi my name is pitambar'.replace('pitambar','tukaram')
# Out:
# 'hi my name is tukaram'

# %%
a = 'hi my name is pitambar'
print(a.replace('pitambar','tukaram'))
print(a)   # main string madhe change
# Out:
# hi my name is tukaram
# hi my name is pitambar

# %%
"hi my name is gio".replace('gio','pitambar')
# Out:
# 'hi my name is pitambar'

# %% [markdown]
# ## isalnum/ isalpha/ isdigit/ isidentifier

# %%
'pitambar1234'.isalnum() # it is checking the alphbet ahe ka va number ahe ka
# Out:
# True

# %%
'pitambar1234%'.isalnum() # it is checking the alphbet ahe ka va number ahe ka  -> symbol ala ki error denar
# Out:
# False

# %%
'nitish'.isalpha()
# Out:
# True

# %%
'12355askasnd'.isalpha()  #-> its checking the only alphabets
# Out:
# False

# %%
'12355'.isdigit()  #-> its checking the only alphabets
# Out:
# True

# %%
'pitambar1234'.isidentifier()
# Out:
# True

# %%
'1pitambar1234'.isidentifier()
# Out:
# False

# %% [markdown]
# ## split and join
# - split () function string madhil word list madhe convert karu shakata ->space,(,)
# - list la use karun string madhe convert karu shakatat

# %%
"hi my name is pitambare this your name".split(" ")
# Out:
# ['hi', 'my', 'name', 'is', 'pitambare', 'this', 'your', 'name']

# %%
"hi my name is pitambare this your name".split('i') # me jaya thiakni (i) ahe tya thikani split kel ahe
# Out:
# ['h', ' my name ', 's p', 'tambare th', 's your name']

# %%
"".join(['hi', 'my', 'name', 'is', 'pitambare', 'this', 'your', 'name'])
# Out:
# 'himynameispitambarethisyourname'

# %%
" ".join(['hi', 'my', 'name', 'is', 'pitambare', 'this', 'your', 'name'])
# Out:
# 'hi my name is pitambare this your name'

# %%
"-".join(['hi', 'my', 'name', 'is', 'pitambare', 'this', 'your', 'name'])
# Out:
# 'hi-my-name-is-pitambare-this-your-name'

# %%
"8".join(['hi', 'my', 'name', 'is', 'pitambare', 'this', 'your', 'name'])
# Out:
# 'hi8my8name8is8pitambare8this8your8name'

# %% [markdown]
# # practice

# %%
# Find the length of a given string without using the len() function

s = input('enter the string: >')

counter = 0

for i in s:
  counter += 1

print('length of string is -:',counter)
# Out:
# length of string is -: 4

# %%
# Extract username from a given email. 
# Eg if the email is nitish24singh@gmail.com 
# then the username should be nitish24singh

s = input('enter the email')

pos = s.index('@')
print(s[0:pos])


            # second codde that 

# mail = "pitusalgare@gmail.com"
# char = ""
# for i in mail:
#     if i == '@':
#         break
#     else:
#         char = char+i

# print(char)
# Out:
# hel

# %%
# Count the frequency of a particular character in a provided string. 
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.

s = input('enter the email -<')
term = input('what would like to search for ->')

counter = 0
for i in s:
  if i == term:
    counter += 1

print('frequency',counter)


        # another code ahe 
# s =  input('enter the email')
# term = input('what would like to search for')
# s.count(term)
# Out:
# enter the email -< ji jo ko lo fo th nj
# what would like to search for -> j
# frequency 3

# %%
# Write a program which can remove a particular character from a string.

s = input('enter the string:')
term = input('what would like to remove:')

result = ''
for i in s:
  if i != term:
    result = result + i
print(result)

        # another code 
# s = input('enter the string:')
# term = input('what would like to remove:')
# s.replace(term,"")
# Out:
# u gy tv v tgb

# %%
# Write a program that can check whether a given string is palindrome or not.
# abba
# malayalam

s = input('enter the string')
flag = True
for i in range(0,len(s)//2):
  if s[i] != s[len(s) - i -1]:
    flag = False
    print('Not a Palindrome')
    break

if flag:
  print('Palindrome')




      # another code jeki maza ahe 


# s = input('enter the string')
# length = len(s)
# line1 = s[0:length]
# line2 = s[-1:-(length+1):-1]
# if line1 == line2:
#     print("palindrom")
# else:
#     print("not palindrom")
# Out:
# Palindrome

# %%
s = input('enter the string')
length = len(s)
line1 = s[0:length]
line2 = s[-1:-(length+1):-1]
# print(line2)
# print(length)
if line1 == line2:
    print("palindrom")
else:
    print("not palindrom")
# Out:
# enter the string malaylam
# not palindrom

# %%
# Write a program to count the number of words in a string without split()

s = input('enter the string : >')
L = []
temp = ''
for i in s:
  if i != ' ':
    temp = temp + i
  else:
    L.append(temp)
    temp = ''

L.append(temp)
print(L)
# Out:
# ['hey', 'this', 'is', 'pitambar', 'taking', 'about', 'my', 'self', 'i', 'gruaduate', 'from', 'sppu', 'unversity', 'in', 'electronic', 'stream', 'and', 'also', 'i', 'done', 'pgcp', 'bda', 'from', 'cdac', 'mumbai', '']

# %%
# Write a python program to convert a string to title case without using the title()
s = input('enter the string : >')

L = []
for i in s.split():
  L.append(i[0].upper() + i[1:].lower())

print(" ".join(L))
# Out:
# Sfffc

# %%
# Write a program that can convert an integer to string.

number = int(input('enter the number'))

digits = '0123456789'
result = ''
while number != 0:
  result = digits[number % 10] + result
  number = number//10

print(result)
print(type(result))
# Out:
# enter the number 10023
# 10023
# <class 'str'>

# %%
# Write a program that can convert an integer to string.

number = int(input('enter the number'))

digits = '0123456789'
result = ''
while number != 0:
  result = str(number % 10) + result
  number = number//10

print(result)
print(type(result))
# Out:
# 4555
# <class 'str'>
