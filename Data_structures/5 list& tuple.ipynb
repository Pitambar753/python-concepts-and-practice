# %%
l = [1,345,45,True,(5+4j),345.45,"pi"]    # IN THAT LIST STORE {INT,FLOAT,STRING,LIST,SET,TUPLE,BOOL,ETC]
l
# Out:
# [1, 345, 45, True, (5+4j), 345.45, 'pi']

# %% [markdown]
#  # types
#  - 1D list

# %%
[1, 345, 45, True, (5+4j), 345.45, 'pi']
# Out:
# [1, 345, 45, True, (5+4j), 345.45, 'pi']

# %%
print(l[0])                                        # ACCESS THE ELEMENT INDEXING VISE
l[6]
# Out:
# 1
# 'pi'

# %%
print(l[0:3])                                   # SLICING 
l[-1]
# Out:
# [1, 345, 45]
# 'pi'

# %%
l[::-1]                         # reverse
# Out:
# ['pi', 345.45, (5+4j), True, 45, 345, 1]

# %%
l[::2]    #even idexing nusar element kadale ahet
# Out:
# [1, 45, (5+4j), 'pi']

# %%
s = "pitambar"

# %%
l+s           # (l -> list , s-> string )  two data types add karu shakat nahi
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 l+s           # (l -> list , s-> string )  two data types add karu shakat nahi
#
# TypeError: can only concatenate list (not "str") to list

# %%
list([s])+l   #  TYPE CASTING JAR KELE TAR
# Out:
# ['pitambar', 1, 345, 45, True, (5+4j), 345.45, 'pi']

# %%
p = "hi my name"

# %%
list([p])+l    # string add kela tar first index la jato
# Out:
# ['hi my name', 1, 345, 45, True, (5+4j), 345.45, 'pi']

# %%
l
# Out:
# [1, 345, 45, True, (5+4j), 345.45, 'pi']

# %%
type(l[6])             # ELEMENT HA WHICH TYPE AHE TE SUDHA KALATAY
# Out:
# str

# %%
l[6][0:1]
# Out:
# 'p'

# %%
str(l[3])[0:2]    # bool value hoti tayla string madhe convert kele "true" madhil 'tr' kadayache hote use -> [0:2]
# Out:
# 'Tr'

# %%
l1 = [3,4,5]

# %%
l + l1
# Out:
# [1, 345, 45, True, (5+4j), 345.45, 'pi', 5, 'pitambar', 3, 4, 5]

# %%
print(l1*3)
l1
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]
# [3, 4, 5]

# %%
len(l1+l)
# Out:
# 12

# %%
l.append(5)     # append use for add (DATA TYPE) LIKE [STRING ,INT,FLOAT,LIST,TUPLE,SET,AND MORE] 
                 # add kele lela data last la add hoto
l
# Out:
# [1, 345, 45, True, (5+4j), 345.45, 'pi', 5]

# %%
s
# Out:
# 'pitambar'

# %%
l.append(s)           # append add in last in indexing 

l
# Out:
# [1, 345, 45, True, (5+4j), 345.45, 'pi', 5, 'pitambar']

# %%
l.append(l1)          # append try only one item to add 
l1
# Out:
# [3, 4, 5]

# %%
l.remove("pitambar")

# %%
l[11][1:2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 l[11][1:2]
#
# IndexError: list index out of range

# %%
l.extend(["pitambar"])
l
# Out:
# [1, 345, 45, True, (5+4j), 345.45, 'pi', 5, 'pitambar']

# %%
l.extend(4)          # To append elements from another list to the current list, use the extend() method
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
thislist = ["apple", "banana", "cherry"]      # To append elements from another list to the current list, use the extend() method
tropical = ["mango", "pineapple", "papaya"] 
thislist.extend(tropical)         #The extend() method does not have to append lists, you can add any
                                   #iterable object (tuples, sets, dictionaries etc
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
l.remove("pitambar")    #The remove() method removes the specified item.
l
# Out:
# [1, 345, 45, True, (5+4j), 345.45, 'pi']

# %%
l.remove(l1)
l
# Out:
# [1, 345, 45, True, (5+4j), 345.45, 'pi', 5, 4]

# %%
l1
l1.insert(1,"pio")        # INSERT JAY INDEX LA SAGITAL AHE TYA INDEX LA TO add hoto

l1
# Out:
# [3, 'pio', 4, 5]

# %%
l1.insert(-1,45)     # The insert() method inserts an item at the specified index:

l1
# Out:
# [3, 'pio', 4, 45, 5]

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(1, "orange")
print(thislist)
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %%
l.pop()       # If you do not specify the index, the pop() method removes the last item.
# Out:
# 'pi'

# %%
thislist = ["apple", "banana", "cherry"]       #The pop() method removes the specified index.
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]             # The del keyword also removes the specified index:
print(thislist)
# Out:
# ['banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()        #The clear() method empties the list.
print(thislist)          #The list still remains, but it has no content.
# Out:
# []

# %%
l
# Out:
# [1, 345, 45, True, (5+4j), 345.45, 'pi', 5, 'pitambar']

# %%
l1 = [3,5,[2,45,7],[2,45,7],7]

# %%
l1.remove(7)                         # remove ->
l1
# Out:
# [3, 5, [2, 45, 7], [2, 45, 7]]

# %%
l1.append([2,45,7])   # jar two value add karyala gelo ki add hot nahi 
l1
# Out:
# [3, 5, [45, 7], [2, 45, 7], [2, 45, 7], [2, 45, 7]]

# %%
l1
l1[2].remove(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 l1
# ----> 2 l1[2].remove(2)
#
# ValueError: list.remove(x): x not in list

# %%
l1
# Out:
# [3, 5, [45, 7], [2, 45, 7], [2, 45, 7], [2, 45, 7]]

# %%
l1
l1[1].remove("p")          # remove string madhil [char] remove karu shakat nahi 
l1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 2
#       1 l1
# ----> 2 l1[1].remove("p")          # remove string madhil [char] remove karu shakat nahi
#       3 l1
#
# AttributeError: 'str' object has no attribute 'remove'

# %%
l1.append(4)
l1
# Out:
# [3, 5, [45, 7], [2, 45, 7], 4]

# %%
l1.remove(4)
l1
# Out:
# [3, 5, [45, 7], [2, 45, 7]]

# %%
l1
# Out:
# [3, 5, [45, 7], [2, 45, 7]]

# %%
l1[::-1]                    # ha REVERSE -> HA JO REVERSE AHE TO temperery reverse karto
# Out:
# [[2, 45, 7], [45, 7], 5, 3]

# %%
l1
#l1.reve
# Out:
# [3, 5, [45, 7], [2, 45, 7]]

# %%
l1.reverse()                # fun reverse -> ha jo reverse ahe to permanent reverse karto

# %%
l1
# Out:
# [[2, 45, 7], [45, 7], 5, 3]

# %%
l2 = [122,45,78,5,3,7,8,]

# %%
l2.sort()               # sort -> ascending order me hot jatay
l2
# Out:
# [3, 5, 7, 8, 45, 78, 122]

# %%
l4 = ["piti", "dio ", "sudh","prem","lol"]

# %%
l4.sort()
l4
# Out:
# ['dio ', 'lol', 'piti', 'prem', 'sudh']

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort()
print(thislist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
l4.sort(reverse=True)         # sort(reverse=True) -> descending order may hot jata hai
l4
# Out:
# ['sudh', 'prem', 'piti', 'lol', 'dio ']

# %%
thislist = ["orange", "mango", "kiwi", "pineapple", "banana"]
thislist.sort(reverse = True)
print(thislist)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
l4.index("prem")               # index("value") -> ha that value which index taken that showing
# Out:
# 1

# %%
l4.index("lol")
# Out:
# 3

# %%
l4.count('piti')              # count("value") -> that value how many time in the list ,it's tell
# Out:
# 1

# %%
tea_varities = ['black','white', 'masala','green']

# %%
tea_varities[1:3] = ["lemon","oolong"]

# %%
tea_varities
# Out:
# ['black', 'lemon', 'oolong', 'green']

# %%
tea_varities[1:2]               #  jar asa kele tar jise start hua vahi end hoga
# Out:
# ['lemon']

# %%
tea_varities[1:1] = ['test','test']        #but tyala vatatya ki add on karayach ahe

# %%
tea_varities
# Out:
# ['black', 'test', 'test', 'lemon', 'oolong', 'green']

# %%
tea_varities[1:4] = []

# %%
tea_varities
# Out:
# ['black', 'oolong', 'green']

# %%
# You cannot copy a list simply by typing list2 = list1, because: list2 will only be a reference to list1,
# and changes made in list1 will automatically also be made in list2.

# %%
tea_varities_copy = tea_varities.copy()               # both are  diffrnent object(memory access ) they are diffr in
                                                       # tya mule copy use karanar

# %%
thislist = ["apple", "banana", "cherry"]
mylist_copy = thislist.copy()
print(mylist_copy)
# Out:
# ['apple', 'banana', 'cherry']

# %%
chai_variety = ["lemon", "masala","ginger"]     # list convert to string

print(" ".join(chai_variety))         #  ->( " ".function() ) <- ahet 
chai_variety
# Out:
# lemon masala ginger
# ['lemon', 'masala', 'ginger']

# %% [markdown]
# ## zip

# %%
a = [10, 20, 30, 40, 50] 
b = [1, 2, 3, 4, 5] 


subtracted = list()
for a, b in zip(a, b):
    item = a -b
    subtracted.append(item)

print(subtracted)
# Out:
# [9, 18, 27, 36, 45]

# %% [markdown]
#
# # Tuples
#
# A tuple in Python is similar to a list. The difference between the two is that we cannot change the elements of a tuple once it is assigned whereas we can change the elements of a list.
#
# In short, a tuple is an immutable list. A tuple can not be changed in any way once it is created.
#
# Characterstics
#
# - Ordered
# - Unchangeble
# - Allows duplicate

# %%
# empty
tup = tuple()
print(type(tup))
t2 = ("hello")
print(type(t2),t2)
t3 = ("hello",)
print(type(t3))
t4 = (1,2.5,True,[1,2,3],[4,5,6])
print(type(t4))
t5 = (1,2,3,4,(5,6))
# Out:
# <class 'tuple'>
# <class 'str'> hello
# <class 'tuple'>
# <class 'tuple'>

# %%
t4[4][0]
# Out:
# 4

# %%
print(t4)    # purn tuple delet hoto specific value delete hot nahi 
del t4        
print(t4)
# Out:
# (1, 2.5, True, [1, 2, 3], [4, 5, 6])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 print(t4)    # purn tuple delet hoto specific value delete hot nahi
#       2 del t4
# ----> 3 print(t4)
#
# NameError: name 't4' is not defined

# %%
del t5[-1]   # specific value la delete karta yet nahi
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 del t5[-1]   # specific value la delete karta yet nahi
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
print(t5[0]) 
t5[0] = 100    # tuple madhe edit nahi hot beca they are immutable
# Out:
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 print(t5[0])
# ----> 2 t5[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(t3)
# tuple madhe adding possible nahi
# Out:
# ('hello',)

# %%
T = (2,4,5,'PITA',45.5,False,(45+5j),[3,4,5])      # tuple madhe all type data can store

# %%
type(T)          #Tuple items are ordered, unchangeable, and allow duplicate values
# Out:
# tuple

# %%
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
len(T)                            # A tuple is a collection which is ordered and unchangeable.
# Out:
# 8

# %%
T[0]
T[-1]
# Out:
# [3, 4, 5]

# %%
T[::1]
# Out:
# (2, 4, 5, 'PITA', 45.5, False, (45+5j), [3, 4, 5])

# %%
T[::-1]
# Out:
# ([3, 4, 5], (45+5j), False, 45.5, 'PITA', 5, 4, 2)

# %%
T[1] = 8                # tuple are the immutable(unchangeable) ahe
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 T[1] = 8
#
# TypeError: 'tuple' object does not support item assignment

# %%
T        # When we say that tuples are ordered, 
# it means that the items have a defined order, and that order will not change.
# Out:
# (2, 4, 5, 'PITA', 45.5, False, (45+5j), [3, 4, 5])

# %%
T.count(50)
# Out:
# 0

# %%
T.count(4)
# Out:
# 1

# %%
T.count(5)
# Out:
# 1

# %%
T.count([3,4,5,])
# Out:
# 1

# %%
T.index(False)          # fun (index ) -> that mean index tell you which are the index
# Out:
# 5

# %%
thistuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)

x = thistuple.index(8)

print(x)
# Out:
# 3

# %%
t = ('black','green','oolong')

# %%
t
# Out:
# ('black', 'green', 'oolong')

# %%
(blac,gn,oolong) = t         # (blac,gn,oolong) ->ya three la variable sarkha use kele ahe 
                            # tuple (t) t ne tuple madhil value insert kele jat ahe

# %%
blac
# Out:
# 'black'

# %%
gn
# Out:
# 'green'

# %% [markdown]
# ## membership operation

# %%
thistuple = ("apple", "banana", "cherry")
if "apple" in thistuple:               # (membership) -> operation ahe brr ka 
  print("Yes, 'apple' is in the fruits tuple")
# Out:
# Yes, 'apple' is in the fruits tuple

# %%
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
                  # "unpacking"

fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits       #But, in Python, we are also allowed to extract the values
                                     # back into variables. This is called "unpacking"
print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %%
                  # (*)Asterisk
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")

(green, yellow, *red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %%
              # Asterisk
fruits = ("apple", "mango", "papaya", "pineapple", "cherry")

(green, *tropic, red) = fruits

print(green)
print(tropic)
print(red)
# Out:
# apple
# ['mango', 'papaya', 'pineapple']
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
for i in range(len(thistuple)):                  # iteration ahe 
  print(thistuple[i])
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ## operation of tuple (+,*,)

# %%
                      #Join Tuples
tuple1 = ("a", "b" , "c")    
tuple2 = (1, 2, 3)

tuple3 = tuple1 + tuple2      # (+) -> operation ahe brr ka 
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
                    #Join Tuples(Multiply Tuples)
fruits = ("apple", "banana", "cherry")
mytuple = fruits * 2          # (*) -> operation ahe brr ka 

print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %%
# tuple function 

thistuple = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)
print(len(thistuple))
print(sum(thistuple))
print(max(thistuple))
print(min(thistuple))
print(sorted(thistuple))
# print(sorted(reverse=thistuple))
print(sorted(thistuple, reverse = True))
# Out:
# 10
# 54
# 8
# 1
# [1, 3, 4, 5, 5, 6, 7, 7, 8, 8]
# [8, 8, 7, 7, 6, 5, 5, 4, 3, 1]

# %%
# zip        # zip ya object ne dona (list, tuple,set ,dict ase karu shakatat)
tip1 = (1,3,56,6,"jio")
tip2 = (2,5,6,8,9,)
l = [1,4,5,6,7,8,9,6]

print(list(zip(tip1,tip2)))
print(tuple(zip(tip1,tip2)))
A = list(zip(l,tip1,tip2))
print(A)
# Out:
# [(1, 2), (3, 5), (56, 6), (6, 8), ('jio', 9)]
# ((1, 2), (3, 5), (56, 6), (6, 8), ('jio', 9))
# [(1, 1, 2), (4, 3, 5), (5, 56, 6), (6, 6, 8), (7, 'jio', 9)]

# %%
help(zip())
# Out:
# Help on zip object:
#
# class zip(object)
#  |  zip(*iterables, strict=False) --> Yield tuples until an input is exhausted.
#  |
#  |     >>> list(zip('abcdefg', range(3), range(4)))
#  |     [('a', 0, 0), ('b', 1, 1), ('c', 2, 2)]
#  |
#  |  The zip object yields n-length tuples, where n is the number of iterables
#  |  passed as positional arguments to zip().  The i-th element in every tuple
#  |  comes from the i-th iterable argument to zip().  This continues until the
#  |  shortest argument is exhausted.
#  |
#  |  If strict is true and one of the arguments is exhausted before the others,
#  |  raise a ValueError.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  __setstate__(...)
# ...

# %%
tip2 = (2,5,6,8,9)

# %%
tup = (4, 5, 1, 2, 3, 5)
t1 = list(tup)
a = [i*2 for i in t1 ]
b = tuple(a)
print(b)
# Out:
# (8, 10, 2, 4, 6, 10)

# %% [markdown]
# ### Difference between Lists and Tuples
#
# - Syntax  -> tuple()  {list[]}
# - Mutability -> tuple are immutable   {list are mutable}
# - Speed -> tuples are faster
# - Memory -> tuple are min space
# - Built in functionality -> more in list
# - Error prone -> list is more error prone
# - Usability ->

# %%
 # speed 
import time 

L = list(range(1000000))
T = tuple(range(1000000))

start = time.time()
for i in L:
  i*5
print('List time',time.time()-start)

start = time.time()
for i in T:
  i*5
print('Tuple time',time.time()-start)
# Out:
# List time 0.059507131576538086
# Tuple time 0.06035590171813965

# %%
import sys

L = list(range(10000))
T = tuple(range(10000))

print('List size',sys.getsizeof(L))
print('Tuple size',sys.getsizeof(T))
# Out:
# List size 80056
# Tuple size 80040

# %%
# tuple
a = (1,2,3)
b = a

a = a + (4,)
print(a)
print(b)
# Out:
# (1, 2, 3, 4)
# (1, 2, 3)

# %%
# list
a = [1,2,3]
b = a

a.append(4)
print(a)
print(b)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %% [markdown]
# # why we use tuple
#
# ## Special syntax

# %%
# tuple unpacking 
a,b,c = (1,2,3)
print(a,b,c)
# Out:
# 1 2 3

# %%
# swap 
a,b = 1,2
b,a = a,b
print(a,b)
# Out:
# 2 1

# %%
a,b, *others = (1,5,4,8,9,7)
print(a,b)
print(others)
# Out:
# 1 5
# [4, 8, 9, 7]

# %%
# zip        # zip ya object ne dona (list, tuple,set ,dict ase karu shakatat)
tip1 = (1,3,56,6,"jio")
tip2 = (2,5,6,8,9,)
list(zip(tip1,tip2))
tuple(zip(tip1,tip2))
# Out:
# ((1, 2), (3, 5), (56, 6), (6, 8), ('jio', 9))
